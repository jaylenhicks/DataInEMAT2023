# %% [markdown]
# #### Reference https://www.youtube.com/watch?v=2mSwcRb3KjQ I used this video as a reference to help guide me through the Youtube API in completing this report

# %% [markdown]
# Explain the purpose of the analysis (what questions and motivations drive you?)
#     The purpose of the analysis is to see if cancel culture results in a decline in the consumption of content.
# Explain the starting point (what brought you here, are there others you are following?)
#     The starting point was to pick some channels the have been canceled.
# Explain the source of the data (where did this data come from, what value does it have?)
#     The source of the data is coming straight from Youtube and Google APIs
# Explain the structure of the data (how is it organized, what pieces of information are included, which pieces will you use?) (these last two are the data ethnographies portions)
#     Data is orginized based on metric catagories: likes, dislikes, comments, timestamps etc.
# Explain what you did (how was the data cleaned/changed, what analysis was conducted and why?)
#     I orginized which sets of metric data would be valuable in determining cancel culture's effectiveness
# Explain what the results mean (what have you learned, what new questions need to be asked, what are your limitations/blindspots?)
#     There is no way to determine if it is effective or not, so I will need to come up with a standard to determine if a cancel was effective
# Explain your conclusion (what should your audience take away from the report?)
#     I would want the audience to look at the data and see how views and other data change over time.

# %%
import requests
import base64
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from googleapiclient.discovery import build 
import json
secrets_filename = 'API_KEY.txt'
api_keys = {}
youtube = build('youtube', 'v3', developerKey=API_KEY)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 10
#       8 secrets_filename = 'API_KEY.txt'
#       9 api_keys = {}
# ---> 10 youtube = build('youtube', 'v3', developerKey=API_KEY)
#
# NameError: name 'API_KEY' is not defined

# %%
ellen_id = "UCp0hYYBW6IMayGgR-WeoCvQ"
colleen_id = "UCrbSjN1_5U7hqFKRA0nvFXQ"
logan_id = "UCG8rbF3g2AMX70yOd8vqIZg"
will_id = "UCKuHFYu3smtrl2AwwMOXOlg"
pew_id = "UC-lHJZR3Gqxm24_Vd_AJ5Yw"

# %%
channel_id = "UCrbSjN1_5U7hqFKRA0nvFXQ"

# %%
def get_channel_stats(youtube, channel_id):
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=channel_id
    )
    response = request.execute()
    
    return response['items']

# %%
channel_stats = get_channel_stats(youtube, channel_id)

# %%
playlist_id = channel_stats[0]['contentDetails']

# %%
def get_video_list(youtube, upload_id):
    video_list = []
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=upload_id,
        maxResults=50
    )
    next_page = True
    while next_page:
        response = request.execute()
        data = response['items']

        for video in data:
            video_id = video['contentDetails']['videoId']
            if video_id not in video_list:
                video_list.append(video_id)

        if 'nextPageToken' in response.keys():
            next_page = True
            request = youtube.playlistItems().list(
                part="snippet,contentDetails",
                playlistId=upload_id,
                pageToken=response['nextPageToken'],
                maxResults=50
            )
        else:
            next_page = False

    return video_list

# %%
channel_stats = get_channel_stats(youtube, channel_id)

# %%
playlist_id = channel_stats[0]['contentDetails']['relatedPlaylists']['uploads']
playlist_id
# Out:
# 'UUrbSjN1_5U7hqFKRA0nvFXQ'

# %%
video_list = get_video_list(youtube, playlist_id)

# %%
def get_video_details(youtube, video_list):
    stats_list=[]

    for i in range(0, len(video_list), 50):
        request= youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=video_list[i:i+50]
        )

        data = request.execute()
        for video in data['items']:
            title=video['snippet']['title']
            published=video['snippet']['publishedAt']
            description=video['snippet']['description']
            tag_count= len(video['snippet'].get('tags',[]))
            view_count=video['statistics'].get('viewCount',0)
            like_count=video['statistics'].get('likeCount',0)
            dislike_count=video['statistics'].get('dislikeCount',0)
            comment_count=video['statistics'].get('commentCount',0)
            stats_dict=dict(title=title, description=description, published=published, tag_count=tag_count, view_count=view_count, like_count=like_count, dislike_count=dislike_count, comment_count=comment_count)
            stats_list.append(stats_dict)

    return stats_list

# %%
video_data = get_video_details(youtube, video_list)

# %%
df=pd.DataFrame(video_data)
df['title_length'] = df['title'].str.len()
df["view_count"] = pd.to_numeric(df["view_count"])
df["like_count"] = pd.to_numeric(df["like_count"])
df["dislike_count"] = pd.to_numeric(df["dislike_count"])
df["comment_count"] = pd.to_numeric(df["comment_count"])
# reaction used later add up likes + dislikes + comments
df["reactions"] = df["like_count"] + df["dislike_count"] + df["comment_count"] + df["comment_count"]
df.head()
# Out:
#                                                title  \
# 0  MARSHALLS HAUL! KIDS BIRTHDAY & CHRISTMAS PRES...
# 1           Christmas Lights & Home Renovation Plans
# 2                   TIKTOK CHAMOY PICKLE TASTE TEST!
# 3                I GOT SO MANY COMMENTS LIKE THIS! 😩
# 4                            TAYLOR SWIFT COPIED ME!
#
#                                          description             published  \
# 0  Donate to Colleen Ballinger's Childhood Cancer...  2023-12-10T22:00:34Z
# 1  Donate to Colleen Ballinger's Childhood Cancer...  2023-12-08T22:10:18Z
# 2  Donate to Colleen Ballinger's Childhood Cancer...  2023-12-07T22:12:15Z
# 3  Donate to Colleen Ballinger's Childhood Cancer...  2023-12-07T00:10:12Z
# 4  Donate to Colleen Ballinger's Childhood Cancer...  2023-12-05T21:54:18Z
#
#    tag_count  view_count  like_count  dislike_count  comment_count  \
# 0         25       63400        4517              0            221
# 1         22       97191        5547              0            384
# 2         23       92553        5894              0            431
# 3         19      120521        6727              0            684
# 4         24       95598        6036              0            565
#
#    title_length  reactions
# 0            51       4959
# 1            40       6315
# 2            32       6756
# 3            35       8095
# 4            23       7166

# %%
chart = sns.displot( a=df["tag_count"], hist=True, kde=False, rug=False )
chart.set(xlabel='Number of Tags Used', ylabel='Occurrences')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 chart = sns.displot( a=df["tag_count"], hist=True, kde=False, rug=False )
#       2 chart.set(xlabel='Number of Tags Used', ylabel='Occurrences')
#
# NameError: name 'sns' is not defined

# %%
df_highest_views = df.nlargest(10, 'view_count')
df_highest_views['title'] = df_highest_views['title'].str[:40]
df_highest_views['view_count_millions'] = df_highest_views['view_count'] / 1000000
df_highest_views
# Out:
#                                          title  \
# 20                                         hi.
# 1113                 Finding out I'm Pregnant!
# 1055  My body Before, During and After Pregnan
# 1056      My pregnant belly right before birth
# 1060                Recovering at the hospital
# 1059                    Bringing my baby home!
# 1088                    I'M IN A DISNEY MOVIE!
# 1072                  PREPARING FOR THE BIRTH!
# 1051                   BABY'S FIRST CHRISTMAS!
# 1061                       it's happening... 😏
#
#                                             description             published  \
# 20    I do not condone or support any kind of online...  2023-06-28T19:24:48Z
# 1113  Make sure to watch the pregnancy reveal video ...  2018-06-29T20:30:00Z
# 1055  Get my new lipstick! - http://mirandasingslips...  2018-12-21T03:22:38Z
# 1056  Get my new lipstick! - http://mirandasingslips...  2018-12-19T02:04:46Z
# 1060  I'm obsessed with my baby. \n\nGet my new lips...  2018-12-15T02:30:43Z
# 1059  Get my new lipstick! - http://mirandasingslips...  2018-12-16T01:02:01Z
# 1088  Hi friends! Thanks for watching my vlog! I lov...  2018-10-07T19:56:34Z
# 1072  We had our first birthing class... I had an in...  2018-11-29T06:25:29Z
# 1051  Get my new lipstick! - http://mirandasingslips...  2018-12-26T23:45:46Z
# 1061  Get my new lipstick! - http://mirandasingslips...  2018-12-10T20:24:38Z
#
#       tag_count  view_count  like_count  dislike_count  comment_count  \
# 20           19    16732843      153728              0          13233
# 1113         22    11918830      368194              0          28347
# 1055         20     9493401      224513              0          15210
# 1056         20     8737759      123023              0           6460
# 1060         24     8563642      383844              0          36409
# 1059         20     7433040      325202              0          22392
# 1088         24     6255260      153461              0          13307
# 1072         26     5429224      109053              0          11210
# 1051         20     5161529      134123              0           7437
# 1061         20     4430733      132272              0          13960
#
#       title_length  reactions  view_count_millions
# 20               3     180194            16.732843
# 1113            25     424888            11.918830
# 1055            43     254933             9.493401
# 1056            36     135943             8.737759
# 1060            26     456662             8.563642
# 1059            22     369986             7.433040
# 1088            22     180075             6.255260
# 1072            24     131473             5.429224
# 1051            23     148997             5.161529
# 1061            19     160192             4.430733

# %%
# Most Interations ( Like + Dislikes + Comments)
df_highest_reactions = df.nlargest(10, 'reactions')
df_highest_reactions['title'] = df_highest_reactions['title'].str[:40]
df_highest_reactions['reactions'] = df_highest_reactions['reactions'] / 1000
df_highest_reactions
# Out:
#                                          title  \
# 1060                Recovering at the hospital
# 1113                 Finding out I'm Pregnant!
# 1059                    Bringing my baby home!
# 606                             My Miscarriage
# 870                      addressing everything
# 1055  My body Before, During and After Pregnan
# 366                     BRINGING MAISY HOME!!!
# 404   What I Didn't Show You From The Twins Bi
# 1058                  Drinking my breast milk!
# 20                                         hi.
#
#                                             description             published  \
# 1060  I'm obsessed with my baby. \n\nGet my new lips...  2018-12-15T02:30:43Z
# 1113  Make sure to watch the pregnancy reveal video ...  2018-06-29T20:30:00Z
# 1059  Get my new lipstick! - http://mirandasingslips...  2018-12-16T01:02:01Z
# 606   TW: This video is about my experience with Pre...  2021-02-08T17:00:16Z
# 870                               addressing everything  2020-05-12T23:14:03Z
# 1055  Get my new lipstick! - http://mirandasingslips...  2018-12-21T03:22:38Z
# 366   Check Out My Merch! - https://fanjoy.co/collec...  2021-12-21T18:00:11Z
# 404   Watch the twins' birth - https://www.youtube.c...  2021-11-11T16:00:04Z
# 1058  Get my new lipstick! - http://mirandasingslips...  2018-12-17T05:09:39Z
# 20    I do not condone or support any kind of online...  2023-06-28T19:24:48Z
#
#       tag_count  view_count  like_count  dislike_count  comment_count  \
# 1060         24     8563642      383844              0          36409
# 1113         22    11918830      368194              0          28347
# 1059         20     7433040      325202              0          22392
# 606          11     3388293      234651              0          31530
# 870           2     4011253      228754              0          26739
# 1055         20     9493401      224513              0          15210
# 366          19     3099790      194367              0          25027
# 404          19     3338730      174425              0          12672
# 1058         20     4091817      155883              0          12983
# 20           19    16732843      153728              0          13233
#
#       title_length  reactions
# 1060            26    456.662
# 1113            25    424.888
# 1059            22    369.986
# 606             14    297.711
# 870             21    282.232
# 1055            43    254.933
# 366             22    244.421
# 404             46    199.769
# 1058            24    181.849
# 20               3    180.194

# %%
# Least Interations ( Like + Dislikes + Comments)
df_least_reactions = df.nsmallest(10, 'reactions')
df_least_reactions['title'] = df_least_reactions['title'].str[:40]
df_least_reactions['reactions'] = df_least_reactions['reactions'] / 1000
df_least_reactions
# Out:
#                                          title  \
# 1388                     BIRTHDAY LIVE STREAM!
# 1430         Song for Bailey Jacob and Parker!
# 1420     LAST NIGHT IN VANCOUVER! LIVE STREAM!
# 1303               the most boring live stream
# 1216  Revealing all the Haters Back Off secret
# 1119                           procrastination
# 0     MARSHALLS HAUL! KIDS BIRTHDAY & CHRISTMA
# 1450                SLUMBER PARTY LIVE STREAM!
# 1163              LIVE STREAM CHRISTMAS PARTY!
# 1444                   I LOVE YOU! Live stream
#
#                                             description             published  \
# 1388  I trust you guys more than anyone so I need to...  2016-09-11T01:31:13Z
# 1430  This song is for my niece Bailey and nephews p...  2016-07-12T02:28:52Z
# 1420  Subscribe to my vlogging channel! - https://ww...  2016-07-26T07:13:24Z
# 1303  I NEED YOUR HELP! \nSubscribe to my vlogging c...  2017-02-20T23:25:38Z
# 1216  Watching episode 6 of Haters Back Off together...  2017-10-11T04:06:53Z
# 1119  Hi friends! Thanks for watching my vlog! I lov...  2018-05-29T22:13:00Z
# 0     Donate to Colleen Ballinger's Childhood Cancer...  2023-12-10T22:00:34Z
# 1450  HI LETS HAVE A SLUMBER PARTYYYY\n\nSubscribe t...  2016-06-19T08:13:52Z
# 1163  Hi friends! Thanks for watching my vlog! I lov...  2017-12-23T02:11:33Z
# 1444  hi! I just wanna say I love you. \n\nSubscribe...  2016-06-27T06:36:50Z
#
#       tag_count  view_count  like_count  dislike_count  comment_count  \
# 1388          0           0           1              0              0
# 1430          6      229070           0              0            106
# 1420          9       60826        3547              0            329
# 1303          9       71546        3807              0            261
# 1216          9       89819        3582              0            421
# 1119          0       79327        4060              0            269
# 0            25       63400        4517              0            221
# 1450          9       81369        4015              0            532
# 1163          7      139955        4609              0            379
# 1444          9       80142        4368              0            509
#
#       title_length  reactions
# 1388            21      0.001
# 1430            33      0.212
# 1420            37      4.205
# 1303            27      4.329
# 1216            42      4.424
# 1119            15      4.598
# 0               51      4.959
# 1450            26      5.079
# 1163            28      5.367
# 1444            23      5.386

# %%
df_highest_disliked = df.nlargest(10, 'dislike_count')
df_highest_disliked['title'] = df_highest_disliked['title'].str[:40]
df_highest_disliked['dislike_count'] = df_highest_disliked['dislike_count'] / 1000
df_highest_disliked
# Out:
#                                       title  \
# 0  MARSHALLS HAUL! KIDS BIRTHDAY & CHRISTMA
# 1  Christmas Lights & Home Renovation Plans
# 2          TIKTOK CHAMOY PICKLE TASTE TEST!
# 3       I GOT SO MANY COMMENTS LIKE THIS! 😩
# 4                   TAYLOR SWIFT COPIED ME!
# 5                    The Last Miranda Shows
# 6   I FINALLY FINISHED MY ROCKS & CRYSTALS!
# 7              My Kids Think I'm Zendaya...
# 8  Taylor Swift Advent and Flynn's Stand Up
# 9        I'm scared... is this Poisonous? 😩
#
#                                          description             published  \
# 0  Donate to Colleen Ballinger's Childhood Cancer...  2023-12-10T22:00:34Z
# 1  Donate to Colleen Ballinger's Childhood Cancer...  2023-12-08T22:10:18Z
# 2  Donate to Colleen Ballinger's Childhood Cancer...  2023-12-07T22:12:15Z
# 3  Donate to Colleen Ballinger's Childhood Cancer...  2023-12-07T00:10:12Z
# 4  Donate to Colleen Ballinger's Childhood Cancer...  2023-12-05T21:54:18Z
# 5  Donate to Colleen Ballinger's Childhood Cancer...  2023-12-04T22:37:59Z
# 6  Donate to Colleen Ballinger's Childhood Cancer...  2023-12-04T00:09:18Z
# 7  Donate to Colleen Ballinger's Childhood Cancer...  2023-12-02T22:34:58Z
# 8  Donate to Colleen Ballinger's Childhood Cancer...  2023-12-01T21:22:27Z
# 9  Donate to Colleen Ballinger's Childhood Cancer...  2023-11-30T21:34:19Z
#
#    tag_count  view_count  like_count  dislike_count  comment_count  \
# 0         25       63400        4517            0.0            221
# 1         22       97191        5547            0.0            384
# 2         23       92553        5894            0.0            431
# 3         19      120521        6727            0.0            684
# 4         24       95598        6036            0.0            565
# 5         19      167093        8026            0.0            554
# 6         19       95031        6332            0.0            485
# 7         26      109350        7013            0.0            583
# 8         19      113186        7675            0.0            745
# 9         23      116496        6985            0.0            793
#
#    title_length  reactions
# 0            51       4959
# 1            40       6315
# 2            32       6756
# 3            35       8095
# 4            23       7166
# 5            22       9134
# 6            39       7302
# 7            28       8179
# 8            48       9165
# 9            34       8571
